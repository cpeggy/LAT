# %%
#Pandas練習

# %%
##確認解碼

# %%
import chardet
with open("104-105年高中職行動學習補助學校名單v1.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
with open("105-106年高中職行動學習補助學校名單v1.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
with open("106-107年高中職行動學習補助學校名單v1.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
with open("107-108年高中職行動學習補助學校名單.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Big5', 'confidence': 0.99, 'language': 'Chinese'}

# %%
import pandas as pd

# %%
## 讓pd讀檔

# %%
h104_105 = pd.read_csv("104-105年高中職行動學習補助學校名單v1.csv",encoding = "utf-8")
h104_105.head()
#test
# Out:
#   學習階段          學校名稱  縣市  地區
# 0   高中      國立基隆高級中學  基隆  北部
# 1   高中    臺北市立永春高級中學  台北  北部
# 2   高中  臺北市立第一女子高級中學  台北  北部
# 3   高中      私立泰北高級中學  台北  北部
# 4   高中    臺北市立陽明高級中學  台北  北部

# %%
Mount104=len(h104_105)
Mount104
# Out:
# 45

# %%
h104_105['年份'] = 104
h104_105
# Out:
#    學習階段            學校名稱  縣市  地區   年份
# 0    高中        國立基隆高級中學  基隆  北部  104
# 1    高中      臺北市立永春高級中學  台北  北部  104
# 2    高中    臺北市立第一女子高級中學  台北  北部  104
# 3    高中        私立泰北高級中學  台北  北部  104
# 4    高中      臺北市立陽明高級中學  台北  北部  104
# 5    高中      臺北市立復興高級中學  台北  北部  104
# 6    高中      臺北市立中崙高級中學  台北  北部  104
# 7    高中      臺北市立麗山高級中學  台北  北部  104
# 8    高中      私立金陵女子高級中學  新北  北部  104
# 9    高中        私立及人高級中學  新北  北部  104
# 10   高職  私立莊敬高級工業家事職業學校  新北  北部  104
# 11   高中      新北市立三民高級中學  新北  北部  104
# 12   高中      新北市立北大高級中學  新北  北部  104
# 13   高中        私立醒吾高級中學  新北  北部  104
# 14   高中      新北市立清水高級中學  新北  北部  104
# 15   高職  國立中壢高級家事商業職業學校  桃園  北部  104
# 16   高中        私立啟英高級中學  桃園  北部  104
# 17   高中    國立中央大學附屬中壢高中  桃園  北部  104
# 18   高中      桃園市立平鎮高級中學  桃園  北部  104
# 19   高中        私立大明高級中學  台中  中部  104
# 20   高中        私立明德高級中學  台中  中部  104
# 21   高中        私立嶺東高級中學  台中  中部  104
# 22   高職    私立光華高級工業職業學校  台中  中部  104
# 23   高中      臺中市立惠文高級中學  台中  中部  104
# ...

# %%
h104_105_N = (h104_105["地區"] == "北部")
h104_105_Nm = len(h104_105[h104_105_N])

h104_105_C = (h104_105["地區"] == "中部")
h104_105_Cm = len(h104_105[h104_105_C])

h104_105_S = (h104_105["地區"] == "南部")
h104_105_Sm = len(h104_105[h104_105_S])

h104_105_E = (h104_105["地區"] == "東部")
h104_105_Em = len(h104_105[h104_105_E])

print("在104年")
print("有",h104_105_Nm,"個北部")
print("有",h104_105_Cm,"個中部")
print("有",h104_105_Sm,"個南部")
print("有",h104_105_Em,"個東部")
# Out:
# 在104年
# 有 21 個北部
# 有 14 個中部
# 有 7 個南部
# 有 3 個東部

# %%
h105_106 = pd.read_csv("105-106年高中職行動學習補助學校名單v1.csv",encoding = "utf-8")
h105_106.head() #test
# Out:
#   學習階段             學校名稱  縣市  地區
# 0   高中    臺南市私立聖功女子高級中學  台南  南部
# 1   高職  臺中市私立光華高級工業職業學校  台中  中部
# 2   高中     臺北市立第一女子高級中學  台北  北部
# 3   高中       南投縣立旭光高級中學  南投  中部
# 4   高中       高雄市立文山高級中學  高雄  南部

# %%
h105_106['年份'] = 105
h105_106
# Out:
#    學習階段               學校名稱   縣市   地區   年份
# 0    高中      臺南市私立聖功女子高級中學   台南   南部  105
# 1    高職    臺中市私立光華高級工業職業學校   台中   中部  105
# 2    高中       臺北市立第一女子高級中學   台北   北部  105
# 3    高中         南投縣立旭光高級中學   南投   中部  105
# 4    高中         高雄市立文山高級中學   高雄   南部  105
# 5    高中      新北市私立金陵女子高級中學   新北   北部  105
# 6    高中         國立新港藝術高級中學   嘉義   中部  105
# 7    高中         臺北市立內湖高級中學   台北   北部  105
# 8    高中         桃園市立平鎮高級中學   桃園   北部  105
# 9    高中        花蓮縣私立海星高級中學   花蓮   東部  105
# 10   高職  高雄市私立三信高級家事商業職業學校  NaN  NaN  105
# 11   高中         臺北市立復興高級中學   台北   北部  105
# 12   高中         新北市立北大高級中學   新北   北部  105
# 13   高中      新竹市私立曙光女子高級中學   新北   北部  105
# 14   高中     臺中市立臺中女子高級中等學校   台中   中部  105
# 15   高中     國立中央大學附屬中壢高級中學   桃園   北部  105
# 16   高職       國立花蓮高級工業職業學校   花蓮   東部  105
# 17   高職  新北市私立莊敬高級工業家事職業學校   新北   北部  105
# 18   高中         新北市立明德高級中學   新北   北部  105
# 19   高中        花蓮縣私立四維高級中學   花蓮   東部  105
# 20   高中         臺北市立陽明高級中學   台北   北部  105
# ...

# %%
h105_106_N = (h105_106["地區"] == "北部")
h105_106_Nm = len(h105_106[h105_106_N])

h105_106_C = (h105_106["地區"] == "中部")
h105_106_Cm = len(h105_106[h105_106_C])

h105_106_S = (h105_106["地區"] == "南部")
h105_106_Sm = len(h105_106[h105_106_S])

h105_106_E = (h105_106["地區"] == "東部")
h105_106_Em = len(h105_106[h105_106_E])

print("在105年")
print("有",h105_106_Nm,"個北部")
print("有",h105_106_Cm,"個中部")
print("有",h105_106_Sm,"個南部")
print("有",h105_106_Em,"個東部")
# Out:
# 在105年
# 有 26 個北部
# 有 10 個中部
# 有 8 個南部
# 有 3 個東部

# %%
Mount105=len(h105_106)
Mount105
# Out:
# 49

# %%
h106_107 = pd.read_csv("106-107年高中職行動學習補助學校名單v1.csv",encoding = "utf-8")
h106_107.head() #test
# Out:
#   學習階段           學校名稱  縣市  地區
# 0   高中     新北市立北大高級中學  新北  北部
# 1   高中     新北市立明德高級中學  新北  北部
# 2   高中     新北市立樹林高級中學  新北  北部
# 3   高中     新北市立錦和高級中學  新北  北部
# 4   高中  新北市私立金陵女子高級中學  新北  北部

# %%
h106_107['年份'] = 106
h106_107
# Out:
#    學習階段               學校名稱  縣市  地區   年份
# 0    高中         新北市立北大高級中學  新北  北部  106
# 1    高中         新北市立明德高級中學  新北  北部  106
# 2    高中         新北市立樹林高級中學  新北  北部  106
# 3    高中         新北市立錦和高級中學  新北  北部  106
# 4    高中      新北市私立金陵女子高級中學  新北  北部  106
# 5    高職  新北市私立莊敬高級工業家事職業學校  新北  北部  106
# 6    高中        新北市私立醒吾高級中學  新北  北部  106
# 1   高中    臺北市立永春高級中學  台北  北部
# 2   高中      臺北市立建國中學  台北  北部
# 3   高中  臺北市立第一女子高級中學  台北  北部
# 4   高中    臺北市立內湖高級中學  台北  北部

# %%
h107_108['年份'] = 107
h107_108
# Out:
#    學習階段               學校名稱  縣市  地區   年份
# 0    高中         臺北市立中崙高級中學  台北  北部  107
# 1    高中         臺北市立永春高級中學  台北  北部  107
# 2    高中           臺北市立建國中學  台北  北部  107
# 3    高中       臺北市立第一女子高級中學  台北  北部  107
# 4    高中         臺北市立內湖高級中學  台北  北部  107
# 5    高中         臺北市立陽明高級中學  台北  北部  107
# 6    高中         臺北市立復興高級中學  台北  北部  107
# 7    高中         臺北市立中正高級中學  台北  北部  107
# 8    高中      新北市私立金陵女子高級中學  新北  北部  107
# 9    高中      新北市財團法人南山高級中學  新北  北部  107
# 10   高職  新北市私立莊敬高級工業家事職業學校  新北  北部  107
# 11   高中         新北市立樹林高級中學  新北  北部  107
# 12   高中         新北市立北大高級中學  新北  北部  107
# 13   高中     國立中央大學附屬中壢高級中學  新北  北部  107
# 14   高中         桃園市立平鎮高級中學  桃園  北部  107
# 15   高中         桃園市立永豐高級中學  桃園  北部  107
# 16   高中      新竹市私立曙光女子高級中學  新竹  北部  107
# 17   高中        新竹市私立磐石高級中學  新竹  北部  107
# 18   高中           國立苑裡高級中學  苗栗  中部  107
# 19   高中        臺中市私立明道高級中學  台中  中部  107
# 20   高中       臺中市私立華盛頓高級中學  台中  中部  107
# 21   高中        臺中市私立葳格高級中學  台中  中部  107
# ...

# %%
h107_108_N = (h107_108["地區"] == "北部")
h107_108_Nm = len(h107_108[h107_108_N])

h107_108_C = (h107_108["地區"] == "中部")
h107_108_Cm = len(h107_108[h107_108_C])

h107_108_S = (h107_108["地區"] == "南部")
h107_108_Sm = len(h107_108[h107_108_S])

h107_108_E = (h107_108["地區"] == "東部")
h107_108_Em = len(h107_108[h107_108_E])

print("在107年")
print("有",h107_108_Nm,"個北部")
print("有",h107_108_Cm,"個中部")
print("有",h107_108_Sm,"個南部")
print("有",h107_108_Em,"個東部")
# Out:
# 在107年
# 有 19 個北部
# 有 9 個中部
# 有 4 個南部
# 有 2 個東部

# %%
Mount107=len(h107_108)
Mount107
# Out:
# 34

# %%
# Creating the DataFrame
data = pd.DataFrame(
    {
    '北部':[h104_105_Nm, h105_106_Nm, h106_107_Nm, h107_108_Nm],
    '中部':[h104_105_Cm, h105_106_Cm, h106_107_Cm, h107_108_Cm],
    '南部':[h104_105_Sm, h105_106_Sm, h106_107_Sm, h107_108_Sm],
    '東部':[h104_105_Em, h105_106_Em, h106_107_Em, h107_108_Em],
    'Total':[Mount104, Mount105, Mount106, Mount107]
    }
)

# Create the index
index_= ['104', '105', '106', '107']

# Set the index
data.index = index_

# Print the DataFrame
print(data)
# Out:
#      北部  中部  南部  東部  Total
# 104  21  14   7   3     45
# 105  26  10   8   3     49
# 106  25  11  11   2     49
# 107  19   9   4   2     34

# %%
data
# Out:
#      北部  中部  南部  東部  Total
# 104  21  14   7   3     45
# 105  26  10   8   3     49
# 106  25  11  11   2     49
# 107  19   9   4   2     34
